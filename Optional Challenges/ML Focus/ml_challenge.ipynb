# %% [markdown]
# # ML Challenge (Optional)

# %% [markdown]
# Train, test, optimize, and analyze the performance of a classification model using a methodology of your choice for the randomly generated moons dataset.
#
# You are not being evaluated for the performance of your model. Instead, we are interested in whether you can implement a simple but rigorous ML workflow.
#
# Show all of your work in this notebook.

# %%
                                                                    # you are free to use any package you deem fit

# %% [markdown]
# ## Dataset

# %%
# DO NOT MODIFY
from sklearn.datasets import make_moons

X, Y = make_moons(random_state = 42, n_samples = (50, 450), noise = 0.25)

# %% [markdown]
# ## Training

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, Y_train)
print(model.intercept_)
# Out:
# 0.7855502172629678

# %%
model.score(X_test, Y_test)
# Out:
# 0.3194502593125166

# %%
import numpy as np
np.mean(np.abs(model.predict(X_test) - Y_test))
# Out:
# 0.18159810355063116

# %% [markdown]
# ## Testing / Optimization

# %%
import matplotlib.pyplot as plt

f = plt.figure(figsize=(12,6))
plt.scatter(X_train[:, 1:2], Y_train, color = "red")
plt.scatter(X_train[:, 1:2], model.predict(X_train), color = "green")

plt.legend(['True Training','Predicted Training'])
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("2-Dimensional Moons")
# Out:
# Text(0.5, 1.0, '2-Dimensional Moons')

# %%
f = plt.figure(figsize=(12,6))
plt.scatter(X_test[:, 1:2], Y_test, color = "blue")
plt.scatter(X_test[:, 1:2], model.predict(X_test), color = "black")

plt.legend(['True Testing','Predicted Testing'])
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("2-Dimensional Moons")
# Out:
# Text(0.5, 1.0, '2-Dimensional Moons')

# %% [markdown]
# ## Performance Analysis

# %% [markdown]
# # '''
# I used a scatterplot similar to that of the tutorial for this challenge, comparing the observed and predicted values such
# that my predicted values trace out moons. However, the models don't quite trace out moons, rather a diagonal line for the model and a horizontal line for the true values. Although there is very little error, with an absolute mean error of only 0.18, the R-squared value of 0.319 means that there is a very weak association between X and Y.
# '''
